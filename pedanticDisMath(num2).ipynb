# %% [markdown]
# Activity 1:
#
#
# Add additional fries and drinks to the order if the customer would buy a Cheese Burger Deluxe and add a Sundae instead if they also do. Always remember to print the receipt for every transaction.
#
#
# p = the customer would buy a Cheese Burger Deluxe
#
#
# q = add additional fries
#
#
# r = add a drink
#
#
# s= add a sundae
#
#
# p → (q ∧ r) ∧ (p → s ∧ ¬q ∧ ¬r)
#
#
# ![Blank diagram (1).jpeg](attachment:7f4c8b95-db5b-4624-a27c-913cd4101db2.jpeg)

# %%
fridri = True
if (fridri):
    print ("You ordered a Cheese Burger Deluxe ")
    print ("and an additional fries and drink will be added to your order.")
else :
    print ("You ordered a Cheese Burger Deluxe and")
    print ("a sundae will be added to your order instead.")
# Out:
# You ordered a Cheese Burger Deluxe
# and an additional fries and drink will be added to the order.
